# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 2</b></center>
# <center><b><h1>Raj Panchasara | 23010101185 | A8</b></center>
# <pre>

# %% [markdown]
# # if..else..

# %% [markdown]
# ### 01) WAP to check whether the given number is positive or negative.

# %%
a = int(input("Enter Number : "))
if(a>-1):
    print("Positive")
else:
    print("Negative")
# Out:
# Enter Number :  -9
# Negative

# %% [markdown]
# ### 02) WAP to check whether the given number is odd or even.

# %%
a = int(input("Enter Number : "))
if(a%2==0):
    print("even")
else:
    print("odd")
# Out:
# Enter Number :  80
# even

# %% [markdown]
# ### 03) WAP to find out largest number from given two numbers using simple if and ternary operator.

# %%
n1 = int(input("Enter Number : "))
n2 = int(input("Enter Number : "))

# simple if
if(n1>n2):
    print(n1)
else:
    print(n2)

# ternary oprater
# Syntax : true_value if (condition) else false_value
print(n1) if(n1>n2) else print(n2)
# Out:
# Enter Number :  -90
# Enter Number :  0
# 0
# 0

# %% [markdown]
# ### 04) WAP to find out largest number from given three numbers.

# %%
num1 = int(input('Enter number 1 : '))
num2 = int(input('Enter number 2 : '))
num3 = int(input('Enter number 3 : '))

if(num1 > num2) :
    if(num1 > num3) :
        print(f'number {num1} is largest')
    else :
        print(f'number {num3} is largest')
else :
    if(num2 > num3) :
        print(f'number {num2} is largest')
    else :
        print(f'number {num3} is largest')
# Out:
# Enter number 1 :  1
# Enter number 2 :  2
# Enter number 3 :  3
# number 3 is largest

# %% [markdown]
# ### 05) WAP to check whether the given year is leap year or not.
# [If a year can be divisible by 4 but not divisible by 100 then it is leap year but if it is divisible by 400 then it is leap year]

# %%
year = int(input('Enter the year : '))

if( year % 4 == 0 or year % 400 == 0) and ( year % 100 != 0) :
    print('Leap Year')
else :
    print('Not a Leap Year')
# Out:
# Enter the year :  2024
# Leap Year

# %% [markdown]
# ### 06) WAP in python to display the name of the day according to the number given by the user.

# %%
num = int(input('Enter number : '))

match num :
    case 1 : print('MONDAY') 
    case 2 : print('TUESDAY')
    case 3 : print('WEDNESDAY')
    case 4 : print('THURSDAY')
    case 5 : print('FRIDAY')
    case 6 : print('SATURDAY')
    case 7 : print('SUNDAY')
    case _ : print('NUMBER MUST BE FROM 1 TO 7')
# Out:
# Enter number :  0
# NUMBER MUST BE FROM 1 TO 7

# %% [markdown]
# ### 07) WAP to implement simple calculator which performs (add,sub,mul,div) of two no. based on user input.

# %%
num1 = int(input('Enter numer 1 : '))
num2 = int(input('Enter numer 2 : '))
temp = int(input('Enter : \n 1 for addition \n 2 for subtraction \n 3 for multiplication \n 4 for division \n ->  '))

if (temp == 1) :
    print('Addition = ' , (num1 + num2))
elif(temp == 2) :
    print('Subtraction = ' , (num1 - num2))
elif(temp == 3) :
    print('Multiplication = ' , (num1 * num2))
elif(temp == 4) :
    print('Division = ' , (num1 / num2))
else :
    print('Invalid Input')
# Out:
# Enter numer 1 :  23
# Enter numer 2 :  32
# Enter :
#  1 for addition
#  2 for subtraction
#  3 for multiplication
#  4 for division
#  ->   1
# Addition =  55

# %% [markdown]
# ### 08) WAP to read marks of five subjects. Calculate percentage and print class accordingly.
# Fail below 35 </br>
# Pass Class between 35 to 45 </br>
# Second Class</br>
# between 45 to 60</br>
# First Class between 60 to 70</br>
# Distinction if more than 70

# %%
m1 = int(input('Enter marks of subject 1 : '))
m2 = int(input('Enter marks of subject 2 : '))
m3 = int(input('Enter marks of subject 3 : '))
m4 = int(input('Enter marks of subject 4 : '))
m5 = int(input('Enter marks of subject 5 : '))

per = ( m1 + m2 + m3 + m4 + m5 ) / 5

if(per > 70) :
    print('Distinction')
elif(per >= 60 and per < 70) :
    print('First Class')
elif(per >= 45 and per < 60) : 
    print('Second Class')
elif(per >= 35 and per < 45) :
    print('Pass')
elif(per >= 0 and per < 35) :
    print('Fail')
else :
    print('Invalid Input')
# Out:
# Enter marks of subject 1 :  36
# Enter marks of subject 2 :  76
# Enter marks of subject 3 :  87
# Enter marks of subject 4 :  90
# Enter marks of subject 5 :  77
# Distinction

# %% [markdown]
# ### 09) Three sides of a triangle are entered through the keyboard, WAP to check whether the triangle is isosceles, equilateral, scalene or right-angled triangle.

# %%
import math
s1 = int(input('Enter marks of side 1 : '))
s2 = int(input('Enter marks of side 2 : '))
s3 = int(input('Enter marks of side 3 : '))

if(s1==s2==s3) :
    print('Equilateral')
elif(s1==s2 or s1==s3 or s2==s3) :
    print('Isosceles')
elif( math.pow(s1,2) + math.pow(s2,2) == math.pow(s3,2) or math.pow(s1,2) + math.pow(s3,2) == math.pow(s2,2) or math.pow(s2,2) + math.pow(s3,2) == math.pow(s1,2) ) :
    print('Right-Angeled')
else :
    print('Scalene')
# Out:
# Enter marks of side 1 :  3
# Enter marks of side 2 :  4
# Enter marks of side 3 :  5
# Right-Angeled

# %% [markdown]
# ### 10) WAP to find the second largest number among three user input numbers.

# %%
num1 = int(input('Enter number 1 : '))
num2 = int(input('Enter number 2 : '))
num3 = int(input('Enter number 3 : '))

if(num1 > num2) :
    if(num1 > num3) :
        if(num2 > num3) :
            print(f'number {num2} is second largest')
        else :
            print(f'number {num3} is second largest')
    else :
        print(f'number {num1} is second largest')
else :
    if(num2 > num3) :
        if(num3 > num1) :
            print(f'number {num3} is second largest')
        else :
            print(f'number {num1} second largest')
    else :
        print(f'number {num2} is second largest')
# Out:
# Enter number 1 :  11
# Enter number 2 :  22
# Enter number 3 :  33
# number 22 is second largest

# %% [markdown]
# ### 11) WAP to calculate electricity bill based on following criteria. Which takes the unit from the user.
# a. First 1 to 50 units – Rs. 2.60/unit</br>
# b. Next 50 to 100 units – Rs. 3.25/unit</br>
# c. Next 100 to 200 units – Rs. 5.26/unit</br>
# d. above 200 units – Rs. 8.45/unit

# %%
units = int(input('Enter units : '))

if(units >= 1 and units < 50) :
    bill = (units * 2.60)
elif(units >= 50 and units < 100) :
    bill = (50 * 2.60) + (units - 50)*3.25
elif(units >=100 and units < 200) :
    bill = (50 * 2.60) + (50 * 3.25) + (units - 100)*5.26
elif(units >= 200) :
    bill = (50 * 2.60) + (50 * 3.25) + (100 * 5.26) + (units - 200)*8.45
else :
    print('Invalid Input')

print('Bill = ', bill)
# Out:
# Enter units :  200
# Bill =  818.5
