# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 10</b></center>
# <center><b><h1>Raj Panchasara | 23010101185 | A8</b></center>
# <pre>

# %% [markdown]
# # Exception Handling

# %% [markdown]
# ### 01) WAP to handle following exceptions:
# 1. ZeroDivisionError
# 2. ValueError
# 3. TypeError
# #### Note: handle them using separate except blocks and also using single except block too.

# %%
try:
    a = int(input("A =  "))
    b = int(input("B =  "))
    c = a / b
    c = (a + 'a')
    
except ZeroDivisionError:
    print("division by zero Error")
    
except ValueError:
    print("Value Error")
    
except TypeError:
    print("Type Error")
# Out:
# A =   1
# B =   0
# division by zero Error

# %% [markdown]
# ### 02)  WAP to handle following exceptions:
# 1. IndexError
# 2. KeyError

# %%
try:
    a = [1, 2, 3]
    print(a[4]) # IndexError

    d = {'a':2, 'b':3, 'c':1}
    print(d['d']) # KeyError
    
except IndexError:
    print('IndexError : list index out of range')
    
except KeyError:
    print('KeyError : key not fount')
# Out:
# IndexError : list index out of range

# %% [markdown]
# ### 03) WAP to handle following exceptions:
# 1. FileNotFoundError
# 2. ModuleNotFoundError

# %%
try:
    f = open('file123.txt','r')
    f.read() # FileNotFoundError

    import raj # ModuleNotFoundError

except FileNotFoundError as e:
    print('FileNotFoundError : ',e)
    
except ModuleNotFoundError as e:
    print('ModuleNotFoundError : ',e)
# Out:
# FileNotFoundError :  [Errno 2] No such file or directory: 'file123.txt'

# %% [markdown]
# ### 04) WAP that catches all type of exceptions in a single except block.

# %%
try:
    a = 2/0
except Exception as e:
    print('Error : ',e)
# Out:
# Error :  division by zero

# %% [markdown]
# ### 05) WAP to demonstrate else  and finally block.

# %%
try:
    a = 2/1
except Exception as e:
    print('Error : ',e)
else :
    print('else Block')
finally:
    print('finally Block')
# Out:
# else Block
# finally Block

# %% [markdown]
# ### 06) Create a short program that prompts the user for a list of grades separated by commas.
# ### Split the string into individual grades and use a list comprehension to convert each string to an integer.
# ### You should use a try statement to inform the user when the values they entered cannot be converted.

# %%
try:
    gl = input("Enter a list of grades separated by commas: ")
    
    grades = [int(grade.strip()) for grade in gl.split(",")]
    print("Grades entered:", grades)
except ValueError:
    print("Error : Please enter only numeric values separated by commas.")
except Exception as e:
    print('Error :',e)

# %% [markdown]
# ### 07) WAP to create an udf divide(a,b) that handles ZeroDivisionError.

# %%
def divide(a, b):
    try:
        return a / b
    except Exception as e:
        print('Error :',e)

divide(1, 0)
# Out:
# Error : division by zero

# %% [markdown]
# ### 08) WAP that gets an age of a person form the user and raises ValueError with error message: "Enter Valid Age" :
# #### If the age is less than 18.
# #### otherwise print the age.

# %%
try :
    age = int(input('Age = '))
    if(age < 18):
        raise ValueError('Value must be greater than 18')
    else:
        print(f'age : {age}')
except ValueError as err:
    print(err)
# Out:
# Age =  10
# Value must be greater than 18

# %% [markdown]
# ### 09) WAP to raise your custom Exception named InvalidUsernameError with the error message : "Username must be between 5 and 15 characters long":
# #### if the given name is having characters less than 5 or greater than 15.
# #### otherwise print the given username.

# %%
class InvalidUsernameError(Exception):
    def __init__(self,msg):
        self.msg = msg
try :
    name = (input('name : '))
    if(len(name) >= 5 and len(name) <= 15):
        print('valid name : ', name)
    else:
        raise InvalidUsernameError('Username must be between 5 and 15 characters long')
except Exception as e:
        print('Error :',e)
# Out:
# name :  12345
# valid name :  12345

# %% [markdown]
# ### 10) WAP to raise your custom Exception named NegativeNumberError with the error message : "Cannot calculate the square root of a negative number" :
# #### if the given number is negative.
# #### otherwise print the square root of the given number.

# %%
import math
class NegativeNumberError(Exception):
    def __init__(self,msg):
        self.msg = msg
try :
    n = int(input('number : '))
    if(n > 0):
        print(f'sgrt of {n} = {math.sqrt(n)}')
    else:
        raise NegativeNumberError('Cannot calculate the square root of a negative number')
except Exception as e:
        print('Error :',e)
# Out:
# number :  2
# sgrt of 2 = 1.4142135623730951
