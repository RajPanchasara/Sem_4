# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 13.2</b></center>
# <center><b><h1>Raj Panchasara | 23010101185 | A8</b></center>
# <pre>

# %% [markdown]
# ## Continued..

# %% [markdown]
# ### 10) Calculate area of a ractangle using object as an argument to a method.

# %%
class Rectangle:
    def __init__(self, length = 0, width = 0):
        self.length = length
        self.width = width

def calculate_area(r):
    return r.length * r.width

rect1 = Rectangle()

r = calculate_area(rect1)
print("Area =", r)

rect2 = Rectangle(10,2)

r2 = calculate_area(rect2)
print("Area =", r2)
# Out:
# Area = 0
# Area = 20

# %% [markdown]
# ### 11) Calculate the area of a square.
# ### Include a Constructor, a method to calculate area named area() and a method named output() that prints the output and is invoked by area().

# %%
class Square:
    def __init__(self,lenght):
        self.lenght = lenght

    def area(self):
        Square_area = self.lenght**2
        self.output(Square_area)

    def output(self, Square_area):
        print(f"Area = {Square_area}")

s = Square(2)
s.area()
# Out:
# Area = 4

# %% [markdown]
# ### 12) Calculate the area of a rectangle.
# ### Include a Constructor, a method to calculate area named area() and a method named output() that prints the output and is invoked by area().
# ### Also define a class method that compares the two sides of reactangle. An object is instantiated only if the two sides are different; otherwise a message should be displayed : THIS IS SQUARE.

# %%
class Rectangle:
    def __init__(self, length, width):
        if length == width:
            print("THIS IS SQUARE.")
        else:
            self.length = length
            self.width = width

    def area(self):
        return self.length * self.width

    def output(self):
        print(f"Rectangle Area: {self.area()}")

    @classmethod
    def validate_sides(cls, length, width):
        if length == width:
            print("THIS IS SQUARE")
            return None
        return cls(length, width)

rect1 = Rectangle.validate_sides(10, 5)
if rect1:
    rect1.output()

rect2 = Rectangle.validate_sides(6, 6)
# Out:
# Rectangle Area: 50
# THIS IS SQUARE

# %% [markdown]
# ### 13) Define a class Square having a private attribute "side".
# ### Implement get_side and set_side methods to accees the private attribute from outside of the class.

# %%
class Square:
    def __init__(self, side):
        self.__side = side

    def get_side(self):
        return self.__side

    def set_side(self, new_side):
        if new_side > 0:
            self.__side = new_side
        else:
            print("Side length must be positive.")

sq = Square(5)
print("Initial Side:", sq.get_side())

sq.set_side(8)
print("Updated Side:", sq.get_side())

sq.set_side(-3)
# Out:
# Initial Side: 5
# Updated Side: 8
# Side length must be positive.

# %% [markdown]
# ### 14) Create a class Profit that has a method named getProfit that accepts profit from the user.
# ### Create a class Loss that has a method named getLoss that accepts loss from the user.
# ### Create a class BalanceSheet that inherits from both classes Profit and Loss and calculates the balanace. It has two methods getBalance() and printBalance().

# %%
class Profit:
    def getProfit(self):
        self.profit = float(input("Enter Profit: "))

class Loss:
    def getLoss(self):
        self.loss = float(input("Enter Loss: "))

class BalanceSheet(Profit, Loss):
    def getBalance(self):
        self.balance = self.profit - self.loss

    def printBalance(self):
        print(f"Net Balance: {self.balance}")

bs = BalanceSheet()
bs.getProfit()
bs.getLoss()
bs.getBalance()
bs.printBalance()
# Out:
# Enter Profit:  100
# Enter Loss:  50
# Net Balance: 50.0

# %% [markdown]
# ### 15) WAP to demonstrate all types of inheritance.

# %%
# Single Inheritance
class Parent:
    def show(self):
        print("Single Inheritance: Parent Class")

class Child(Parent):
    def display(self):
        print("Single Inheritance: Child Class")

obj1 = Child()
obj1.show()
obj1.display()
print()

# Multiple Inheritance
class Mother:
    def motherInfo(self):
        print("Multiple Inheritance: Mother Class")

class Father:
    def fatherInfo(self):
        print("Multiple Inheritance: Father Class")

class Child(Mother, Father):
    def childInfo(self):
        print("Multiple Inheritance: Child Class")

obj2 = Child()
obj2.motherInfo()
obj2.fatherInfo()
obj2.childInfo()
print()

# Multilevel Inheritance
class Grandparent:
    def grandparentInfo(self):
        print("Multilevel Inheritance: Grandparent Class")

class Parent(Grandparent):
    def parentInfo(self):
        print("Multilevel Inheritance: Parent Class")

class Child(Parent):
    def childInfo(self):
        print("Multilevel Inheritance: Child Class")

obj3 = Child()
obj3.grandparentInfo()
obj3.parentInfo()
obj3.childInfo()
print()

# Hierarchical Inheritance
class Parent:
    def parentInfo(self):
        print("Hierarchical Inheritance: Parent Class")

class Child1(Parent):
    def child1Info(self):
        print("Hierarchical Inheritance: Child1 Class")

class Child2(Parent):
    def child2Info(self):
        print("Hierarchical Inheritance: Child2 Class")

obj4 = Child1()
obj5 = Child2()
obj4.parentInfo()
obj4.child1Info()
obj5.parentInfo()
obj5.child2Info()
print()

# Hybrid Inheritance
class Base:
    def baseInfo(self):
        print("Hybrid Inheritance: Base Class")

class Derived1(Base):
    def derived1Info(self):
        print("Hybrid Inheritance: Derived1 Class")

class Derived2(Base):
    def derived2Info(self):
        print("Hybrid Inheritance: Derived2 Class")

class Derived3(Derived1, Derived2):
    def derived3Info(self):
        print("Hybrid Inheritance: Derived3 Class")

obj6 = Derived3()
obj6.baseInfo()
obj6.derived1Info()
obj6.derived2Info()
obj6.derived3Info()
# Out:
# Single Inheritance: Parent Class
# Single Inheritance: Child Class
#
# Multiple Inheritance: Mother Class
# Multiple Inheritance: Father Class
# Multiple Inheritance: Child Class
#
# Multilevel Inheritance: Grandparent Class
# Multilevel Inheritance: Parent Class
# Multilevel Inheritance: Child Class
#
# Hierarchical Inheritance: Parent Class
# Hierarchical Inheritance: Child1 Class
# Hierarchical Inheritance: Parent Class
# Hierarchical Inheritance: Child2 Class
#
# Hybrid Inheritance: Base Class
# Hybrid Inheritance: Derived1 Class
# Hybrid Inheritance: Derived2 Class
# Hybrid Inheritance: Derived3 Class

# %% [markdown]
# ### 16) Create a Person class with a constructor that takes two arguments name and age.
# ### Create a child class Employee that inherits from Person and adds a new attribute salary.
# ### Override the __init__ method in Employee to call the parent class's __init__ method using the super() and then initialize the salary attribute.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class Employee(Person):
    def __init__(self, name, age, salary):
        super().__init__(name, age)
        self.salary = salary

emp = Employee("John Doe", 30, 50000)
print(f"Name: {emp.name}\nAge: {emp.age}\nSalary: {emp.salary}")
# Out:
# Name: John Doe
# Age: 30
# Salary: 50000

# %% [markdown]
# ### 17) Create a Shape class with a draw method that is not implemented.
# ### Create three child classes Rectangle, Circle, and Triangle that implement the draw method with their respective drawing behaviors.
# ### Create a list of Shape objects that includes one instance of each child class, and then iterate through the list and call the draw method on each object.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def draw(self):
        pass

class Rectangle(Shape):
    def draw(self):
        print("Drawing a Rectangle")

class Circle(Shape):
    def draw(self):
        print("Drawing a Circle")

class Triangle(Shape):
    def draw(self):
        print("Drawing a Triangle")

shapes = [Rectangle(), Circle(), Triangle()]

for shape in shapes:
    shape.draw()
# Out:
# Drawing a Rectangle
# Drawing a Circle
# Drawing a Triangle
