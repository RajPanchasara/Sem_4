# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="10"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 1</b></center>
# <center><b><h1>Raj Panchasara | 23010101185 | A8</b></center>
# </pre>

# %% [markdown]
# ### 01) WAP to print “Hello World”

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ### 02) WAP to print addition of two numbers with and without using input().

# %% [markdown]
# <h5>Without Input</h5>

# %%
a, b = 1, 2
print(a + b)
# Out:
# 3

# %% [markdown]
# <h5>With Input</h5>

# %%
c = int(input('c = '))
d = int(input('d = '))
print(c + d)
# Out:
# c =  3
# d =  4
# 7

# %% [markdown]
# ### 03) WAP to check the type of the variable.

# %%
e = 2.3
print(type(e))
# Out:
# <class 'float'>

# %% [markdown]
# ### 04) WAP to calculate simple interest.

# %%
p = int(input('p = '))
r = int(input('r = '))
t = int(input('t = '))
print('Simple Interest = ',(p*r*t)/100)
# Out:
# p =  10
# r =  10
# t =  10
# Simple Interest =  10.0

# %% [markdown]
# ### 05) WAP to calculate area and perimeter of a circle.

# %%
rad = int(input('Enter radius : '))
print('Perimeter = ', (2*3.14*rad), ' and Area = ', (3.14*rad*rad))
# Out:
# Enter radius :  3
# Perimeter =  18.84  and Area =  28.259999999999998

# %% [markdown]
# ### 06) WAP to calculate area of a triangle.

# %%
base = int(input('Enter base : '))
height = int(input('Enter height : '))
print('Area of Triangle is ', ((1/2)*base*height))
# Out:
# Enter base :  2
# Enter height :  3
# Area of Triangle is  3.0

# %% [markdown]
# ### 07) WAP to compute quotient and remainder.

# %%
num1 = int(input('Enter num1 : '))
num2 = int(input('Enter num2 : '))
quotient = int(num1/num2)
remainder = (num1%num2)
print('Quotient = ', quotient, 'Remainder = ', remainder)
# Out:
# Enter num1 :  17
# Enter num2 :  5
# Quotient =  3 Remainder =  2

# %% [markdown]
# ### 08) WAP to convert degree into Fahrenheit and vice versa.

# %% [markdown]
# <h5>Celsius to Fahrenheit</h5>

# %%
cel1 = float(input('Enter temperature in celsius : '))
fah1 = ( cel1 * (9/5) ) + 32
print (fah1)
# Out:
# Enter temperature in celsius :  37
# 98.60000000000001

# %% [markdown]
# <h5>Fahrenheit to Celsius</h5>

# %%
fah2 = float(input('Enter temperature in fahrenheit : '))
cel2 = ( fah2 -32 ) / ( 9 / 5 )
print (cel2)
# Out:
# Enter temperature in fahrenheit :  98
# 36.666666666666664

# %% [markdown]
# ### 09) WAP to find the distance between two points in 2-D space.

# %%
import math

x1 = int(input('Enter x1 : '))
x2 = int(input('Enter x2 : '))
y1 = int(input('Enter y1 : '))
y2 = int(input('Enter y2 : '))

dis = math.sqrt( pow((x2-x1),2) + pow((y2-y1),2) )
print(dis)
# Out:
# Enter x1 :  2
# Enter x2 :  3
# Enter y1 :  1
# Enter y2 :  4
# 3.1622776601683795

# %% [markdown]
# ### 10) WAP to print sum of n natural numbers.

# %%
n = int(input('Enter n : '))
sumOfn = ( n*(n+1) / 2 )
print(sumOfn)
# Out:
# Enter n :  16
# 136.0

# %% [markdown]
# ### 11) WAP to print sum of square of n natural numbers.

# %%
num = int(input('Enter n : '))
sumOfn2 = ( num*(num+1)*((2*num)+1) ) / 6
print(sumOfn2)
# Out:
# Enter n :  4
# 30.0

# %% [markdown]
# ### 12) WAP to concate the first and last name of the student.

# %%
name = input('Enter name : ')
names = name.split(' ')
firstName = names[0]
lastName = names[1]

print('First Name : ', firstName)
print('Last Name : ', lastName)
# Out:
# Enter name :  k r
# First Name :  k
# Last Name :  r

# %% [markdown]
# ### 13) WAP to swap two numbers.

# %%
number1 = int(input('Enter number1 : '))
number2 = int(input('Enter number2 : '))
number3 = number1
number1 = number2
number2 = number3
print('number1 = ', number1)
print('number2 = ', number2)
# Out:
# Enter number1 :  2
# Enter number2 :  3
# number1 =  3
# number2 =  2

# %% [markdown]
# ### 14) WAP to get the distance from user into kilometer, and convert it into meter, feet, inches and centimeter.

# %%
km = int(input('Enter distance in kilometers : '))
mt = km * 1000
ft = km * 3280.84
inc = km * 39370.1
cm = km * 100000

print('Distance in meters = ',mt)
print('Distance in feet = ',ft)
print('Distance in inches = ',inc)
print('Distance in centimeters = ',cm)
# Out:
# Enter distance in kilometers :  2
# Distance in meters =  2000
# Distance in feet =  6561.68
# Distance in inches =  78740.2
# Distance in centimeters =  200000

# %% [markdown]
# ### 15) WAP to get day, month and year from the user and print the date in the given format: 23-11-2024.

# %%
day = int(input('Enter day : '))
month = int(input('Enter month : '))
year = int(input('Enter year : '))

print('Date in given formate is :', end=' ')
print(day, month, year ,sep='-')
# Out:
# Enter day :  23
# Enter month :  11
# Enter year :  2024
# Date in given formate is : 23-11-2024
